# %% [markdown]
# # PyQt GUI 흐름
#
# 최종 GUI는 종목 검색, 차트 표시, 예측 결과 확인, 뉴스 워드클라우드 표시를 목표로 구현했습니다.
#
# 당시 Qt Designer `.ui` 파일과 전체 GUI 구현은 Drive·로컬 보관 자료이며, 이 공개 저장소에는 포함하지 않습니다.
#
# 공개 검토는 `src.app_main`의 진입점과 실제 GUI 화면 자료를 기준으로 진행합니다.

# %%
from src.app_main import DEFAULT_UI_PATH

DEFAULT_UI_PATH

# %% [markdown]
# ## 공개용 정리
#
# 원본 GUI 파일은 길고 DB 접속/워드클라우드/차트 로직이 한 파일에 섞여 있습니다. 공개용 `src/app_main.py`는 UI 실행 진입점만 담당하게 두고, 데이터 수집·DB·모델링·워드클라우드는 별도 모듈로 분리했습니다.
