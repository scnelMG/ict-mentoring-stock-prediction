# %% [markdown]
# # 뉴스 워드클라우드 흐름
#
# 네이버 금융 뉴스 제목을 수집하고 명사를 추출해 워드클라우드로 시각화한 과정을 정리했습니다.
#
# 원본 실험 파일 예시:
# - `financial/네이버_금융_뉴스_크롤링.ipynb`
# - `financial/qt_design/wordcloud.py`

# %%
from src.news_wordcloud import collect_recent_titles, extract_keyword_counts, generate_wordcloud

# titles = collect_recent_titles(min_titles=150)
# counts = extract_keyword_counts(titles)
# generate_wordcloud(counts)

# %% [markdown]
# ## 결과 해석
#
# 워드클라우드는 특정 시점의 금융 뉴스에서 반복적으로 등장한 키워드를 빠르게 확인하기 위한 보조 시각화입니다. 예측 모델의 직접 입력값이라기보다 사용자 화면에서 시장 분위기를 보여주는 역할로 사용했습니다.
